# %%
from pathlib import Path
from bsn_pc.experiments.figure6 import Figure6Experiment

output_root = Path('outputs_notebooks')
exp = Figure6Experiment(output_root=output_root)
artifacts = exp.run(quick=True)
artifacts
